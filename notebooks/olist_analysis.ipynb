# %% [markdown]
# <a href="https://colab.research.google.com/github/buseozgur/brazilian-ecommerce-analysis/blob/main/olist_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Brazilian E-Commerce Analysis (Olist)
#
# This project analyzes Brazilian e-commerce data from Olist (2016–2018)
# to explore customer behavior, order characteristics, and customer satisfaction
# using statistical methods.
#
# ## Analysis Scope
# - Descriptive statistics
# - Correlation analysis
# - A/B testing
# - ANOVA tests

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
# Out:
# drive/  sample_data/
